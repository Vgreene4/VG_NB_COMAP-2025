# %%
import pandas as pd

dropped = pd.read_csv("summerOly_countries_cropped.csv")

# %%
num_NOC_dict = {}

for i in range(0, len(dropped)):
    num_NOC_dict[i] = dropped.iloc[i]["NOC"]

# %%
NOC_num_dict = {}

for i in range(0, len(dropped)):
        NOC_num_dict[dropped.iloc[i]["NOC"]] = i

# %%
def NOC_to_num(NOC):
    NOC_num_dict = {'AFG': 0,
 'AHO': 1,
 'ALB': 2,
 'ALG': 3,
 'AND': 4,
 'ANG': 5,
 'ANT': 6,
 'ARG': 7,
 'ARM': 8,
 'ARU': 9,
 'ASA': 10,
 'AUS': 11,
 'AUT': 12,
 'AZE': 13,
 'BAH': 14,
 'BAN': 15,
 'BAR': 16,
 'BDI': 17,
 'BEL': 18,
 'BEN': 19,
 'BER': 20,
 'BHU': 21,
 'BIH': 22,
 'BIZ': 23,
 'BLR': 24,
 'BOL': 25,
 'BOT': 26,
 'BRA': 27,
 'BRN': 28,
 'BRU': 29,
 'BUL': 30,
 'BUR': 31,
 'CAF': 32,
 'CAM': 33,
 'CAN': 34,
 'CAY': 35,
 'CGO': 36,
 'CHA': 37,
 'CHI': 38,
 'CHN': 39,
 'CIV': 40,
 'CMR': 41,
 'COD': 42,
 'COK': 43,
 'COL': 44,
 'COM': 45,
 'CPV': 46,
 'CRC': 47,
 'CRO': 48,
 'CUB': 49,
 'CYP': 50,
 'CZE': 51,
 'DEN': 52,
 'DJI': 53,
 'DMA': 54,
 'DOM': 55,
 'ECU': 56,
 'EGY': 57,
 'EOR': 58,
 'ERI': 59,
 'ESA': 60,
 'ESP': 61,
 'EST': 62,
 'ETH': 63,
 'FIJ': 64,
 'FIN': 65,
 'FRA': 66,
 'FRG': 67,
 'FSM': 68,
 'GAB': 69,
 'GAM': 70,
 'GBR': 71,
 'GBS': 72,
 'GDR': 73,
 'GEO': 74,
 'GEQ': 75,
 'GER': 76,
 'GHA': 77,
 'GRE': 78,
 'GRN': 79,
 'GUA': 80,
 'GUI': 81,
 'GUM': 82,
 'GUY': 83,
 'HAI': 84,
 'HKG': 85,
 'HON': 86,
 'HUN': 87,
 'INA': 88,
 'IND': 89,
 'IOA': 90,
 'IRI': 91,
 'IRL': 92,
 'IRQ': 93,
 'ISL': 94,
 'ISR': 95,
 'ISV': 96,
 'ITA': 97,
 'IVB': 98,
 'JAM': 99,
 'JOR': 100,
 'JPN': 101,
 'KAZ': 102,
 'KEN': 103,
 'KGZ': 104,
 'KIR': 105,
 'KOR': 106,
 'KOS': 107,
 'KSA': 108,
 'KUW': 109,
 'LAO': 110,
 'LAT': 111,
 'LBA': 112,
 'LBN': 113,
 'LBR': 114,
 'LCA': 115,
 'LES': 116,
 'LIE': 117,
 'LTU': 118,
 'LUX': 119,
 'MAD': 120,
 'MAL': 121,
 'MAR': 122,
 'MAS': 123,
 'MAW': 124,
 'MDA': 125,
 'MDV': 126,
 'MEX': 127,
 'MGL': 128,
 'MHL': 129,
 'MKD': 130,
 'MLI': 131,
 'MLT': 132,
 'MNE': 133,
 'MON': 134,
 'MOZ': 135,
 'MRI': 136,
 'MTN': 137,
 'MYA': 138,
 'NAM': 139,
 'NCA': 140,
 'NED': 141,
 'NEP': 142,
 'NGR': 143,
 'NIG': 144,
 'NOR': 145,
 'NRU': 146,
 'NZL': 147,
 'OMA': 148,
 'PAK': 149,
 'PAN': 150,
 'PAR': 151,
 'PER': 152,
 'PHI': 153,
 'PLE': 154,
 'PLW': 155,
 'PNG': 156,
 'POL': 157,
 'POR': 158,
 'PRK': 159,
 'PUR': 160,
 'QAT': 161,
 'ROU': 162,
 'RSA': 163,
 'RUS': 164,
 'RWA': 165,
 'SAM': 166,
 'SCG': 167,
 'SEN': 168,
 'SEY': 169,
 'SGP': 170,
 'SKN': 171,
 'SLE': 172,
 'SLO': 173,
 'SMR': 174,
 'SOL': 175,
 'SOM': 176,
 'SRB': 177,
 'SRI': 178,
 'SSD': 179,
 'STP': 180,
 'SUD': 181,
 'SUI': 182,
 'SUR': 183,
 'SVK': 184,
 'SWE': 185,
 'SWZ': 186,
 'SYR': 187,
 'TAN': 188,
 'TCH': 189,
 'TGA': 190,
 'THA': 191,
 'TJK': 192,
 'TKM': 193,
 'TLS': 194,
 'TOG': 195,
 'TPE': 196,
 'TTO': 197,
 'TUN': 198,
 'TUR': 199,
 'TUV': 200,
 'UAE': 201,
 'UGA': 202,
 'UKR': 203,
 'URS': 204,
 'URU': 205,
 'USA': 206,
 'UZB': 207,
 'VAN': 208,
 'VEN': 209,
 'VIE': 210,
 'VIN': 211,
 'VNM': 212,
 'YAR': 213,
 'YEM': 214,
 'YUG': 215,
 'ZAM': 216,
 'ZIM': 217}
    return NOC_num_dict[NOC]

def num_to_NOC(num):
    num_NOC_dict = {0: 'AFG',
 1: 'AHO',
 2: 'ALB',
 3: 'ALG',
 4: 'AND',
 5: 'ANG',
 6: 'ANT',
 7: 'ARG',
 8: 'ARM',
 9: 'ARU',
 10: 'ASA',
 11: 'AUS',
 12: 'AUT',
 13: 'AZE',
 14: 'BAH',
 15: 'BAN',
 16: 'BAR',
 17: 'BDI',
 18: 'BEL',
 19: 'BEN',
 20: 'BER',
 21: 'BHU',
 22: 'BIH',
 23: 'BIZ',
 24: 'BLR',
 25: 'BOL',
 26: 'BOT',
 27: 'BRA',
 28: 'BRN',
 29: 'BRU',
 30: 'BUL',
 31: 'BUR',
 32: 'CAF',
 33: 'CAM',
 34: 'CAN',
 35: 'CAY',
 36: 'CGO',
 37: 'CHA',
 38: 'CHI',
 39: 'CHN',
 40: 'CIV',
 41: 'CMR',
 42: 'COD',
 43: 'COK',
 44: 'COL',
 45: 'COM',
 46: 'CPV',
 47: 'CRC',
 48: 'CRO',
 49: 'CUB',
 50: 'CYP',
 51: 'CZE',
 52: 'DEN',
 53: 'DJI',
 54: 'DMA',
 55: 'DOM',
 56: 'ECU',
 57: 'EGY',
 58: 'EOR',
 59: 'ERI',
 60: 'ESA',
 61: 'ESP',
 62: 'EST',
 63: 'ETH',
 64: 'FIJ',
 65: 'FIN',
 66: 'FRA',
 67: 'FRG',
 68: 'FSM',
 69: 'GAB',
 70: 'GAM',
 71: 'GBR',
 72: 'GBS',
 73: 'GDR',
 74: 'GEO',
 75: 'GEQ',
 76: 'GER',
 77: 'GHA',
 78: 'GRE',
 79: 'GRN',
 80: 'GUA',
 81: 'GUI',
 82: 'GUM',
 83: 'GUY',
 84: 'HAI',
 85: 'HKG',
 86: 'HON',
 87: 'HUN',
 88: 'INA',
 89: 'IND',
 90: 'IOA',
 91: 'IRI',
 92: 'IRL',
 93: 'IRQ',
 94: 'ISL',
 95: 'ISR',
 96: 'ISV',
 97: 'ITA',
 98: 'IVB',
 99: 'JAM',
 100: 'JOR',
 101: 'JPN',
 102: 'KAZ',
 103: 'KEN',
 104: 'KGZ',
 105: 'KIR',
 106: 'KOR',
 107: 'KOS',
 108: 'KSA',
 109: 'KUW',
 110: 'LAO',
 111: 'LAT',
 112: 'LBA',
 113: 'LBN',
 114: 'LBR',
 115: 'LCA',
 116: 'LES',
 117: 'LIE',
 118: 'LTU',
 119: 'LUX',
 120: 'MAD',
 121: 'MAL',
 122: 'MAR',
 123: 'MAS',
 124: 'MAW',
 125: 'MDA',
 126: 'MDV',
 127: 'MEX',
 128: 'MGL',
 129: 'MHL',
 130: 'MKD',
 131: 'MLI',
 132: 'MLT',
 133: 'MNE',
 134: 'MON',
 135: 'MOZ',
 136: 'MRI',
 137: 'MTN',
 138: 'MYA',
 139: 'NAM',
 140: 'NCA',
 141: 'NED',
 142: 'NEP',
 143: 'NGR',
 144: 'NIG',
 145: 'NOR',
 146: 'NRU',
 147: 'NZL',
 148: 'OMA',
 149: 'PAK',
 150: 'PAN',
 151: 'PAR',
 152: 'PER',
 153: 'PHI',
 154: 'PLE',
 155: 'PLW',
 156: 'PNG',
 157: 'POL',
 158: 'POR',
 159: 'PRK',
 160: 'PUR',
 161: 'QAT',
 162: 'ROU',
 163: 'RSA',
 164: 'RUS',
 165: 'RWA',
 166: 'SAM',
 167: 'SCG',
 168: 'SEN',
 169: 'SEY',
 170: 'SGP',
 171: 'SKN',
 172: 'SLE',
 173: 'SLO',
 174: 'SMR',
 175: 'SOL',
 176: 'SOM',
 177: 'SRB',
 178: 'SRI',
 179: 'SSD',
 180: 'STP',
 181: 'SUD',
 182: 'SUI',
 183: 'SUR',
 184: 'SVK',
 185: 'SWE',
 186: 'SWZ',
 187: 'SYR',
 188: 'TAN',
 189: 'TCH',
 190: 'TGA',
 191: 'THA',
 192: 'TJK',
 193: 'TKM',
 194: 'TLS',
 195: 'TOG',
 196: 'TPE',
 197: 'TTO',
 198: 'TUN',
 199: 'TUR',
 200: 'TUV',
 201: 'UAE',
 202: 'UGA',
 203: 'UKR',
 204: 'URS',
 205: 'URU',
 206: 'USA',
 207: 'UZB',
 208: 'VAN',
 209: 'VEN',
 210: 'VIE',
 211: 'VIN',
 212: 'VNM',
 213: 'YAR',
 214: 'YEM',
 215: 'YUG',
 216: 'ZAM',
 217: 'ZIM'}
    return num_NOC_dict[num]
